# %%
import requests
from requests.exceptions import HTTPError, Timeout, RequestException

def make_nws_request(endpoint, user_agent):
    """Function to send HTTP request to NWS. 
    Source: https://www.pythonsnacks.com/p/a-guide-on-using-the-national-weather-service-api-with-python"""
    headers = {
        "User-Agent": user_agent,
    }

    try:
        response = requests.get(
                       endpoint, 
                       headers=headers
                   )
        # Raise HTTPError for bad responses (4xx or 5xx)
        response.raise_for_status()
        return response.json()

    except HTTPError as http_err:
        print(f"HTTP error occurred: {http_err} - Status code: {response.status_code}")
    except Timeout as timeout_err:
        print(f"Request timed out: {timeout_err}")
    except RequestException as req_err:
        print(f"Request error: {req_err}")
    
    return None  # Return None if an error occurred

# %%
# Extract data via api, send to gcs bucket
import json
user_agent = 'jacks2224fs@gmail.com'
endpoint = 'https://api.weather.gov/alerts?area=MI&limit=500'

alert_data = make_nws_request(endpoint, user_agent)
print(alert_data)

with open('alert_data.json', 'w') as f:
    json.dump(alert_data['features'], f)
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld', {'@version': '1.1', 'wx': 'https://api.weather.gov/ontology#', '@vocab': 'https://api.weather.gov/ontology#'}], 'type': 'FeatureCollection', 'features': [{'id': 'https://api.weather.gov/alerts/urn:oid:2.49.0.1.840.0.ac59b8df00c8bda31aa21ed460e250a589849d35.001.1', 'type': 'Feature', 'geometry': None, 'properties': {'@id': 'https://api.weather.gov/alerts/urn:oid:2.49.0.1.840.0.ac59b8df00c8bda31aa21ed460e250a589849d35.001.1', '@type': 'wx:Alert', 'id': 'urn:oid:2.49.0.1.840.0.ac59b8df00c8bda31aa21ed460e250a589849d35.001.1', 'areaDesc': 'Baraga; Marquette; Iron; Dickinson; Menominee', 'geocode': {'SAME': ['026013', '026103', '026071', '026043', '026109'], 'UGC': ['MIZ004', 'MIZ005', 'MIZ010', 'MIZ011', 'MIZ012']}, 'affectedZones': ['https://api.weather.gov/zones/forecast/MIZ004', 'https://api.weather.gov/zones/forecast/MIZ005', 'https://api.weather.gov/zones/forecast/MIZ010', 'https://api.weather.gov/zones/forecast/MIZ011', 'https://api.weather.gov/zones/forecast/MIZ012'], 'references': [], 'sent': '2024-12-27T06:49:00-05:00', 'effective': '2024-12-27T06:49:00-05:00', 'onset': '2024-12-27T06:49:00-05:00', 'expires': '2024-12-27T09:00:00-05:00', 'ends': None, 'status': 'Actual', 'messageType': 'Alert', 'category': 'Met', 'severity': 'Moderate', 'certainty': 'Observed', 'urgency': 'Expected', 'event': 'Special Weather Statement', 'sender': 'w-nws.webmaster@noaa.gov', 'senderName': 'NWS Marquette MI', 'headline': 'Special Weather Statement issued December 27 at 6:49AM EST by NWS Marquette MI', 'description': 'Although air temperatures have risen just above freezing, ground\ntemperatures remain near or slightly below freezing in some\nareas. As a result, untreated roads, sidewalks and parking lots\nwill continue to have icy spots early this morning. If traveling,\ndrive with caution.', 'instruction': None, 'response': 'Execute', 'parameters': {'AWIPSidentifier': ['SPSMQT'], 'WMOidentifier': ['WWUS83 KMQT 271149'], 'NWSheadline': ['ICY SPOTS ON ROADS...SIDEWALKS AND PARKING LOTS EARLY THIS MORNING'], 'BLOCKCHANNEL': ['EAS', 'NWEM', 'CMAS'], 'EAS-ORG': ['WXR']}}}, {'id': 'https://api.weather.gov/alerts/urn:oid:2.49.0.1.840.0.6d956cff9c1dfa46d7dd97d88afdebd1df13f0bf.001.1', 'type': 'Feature', 'geometry': None, 'properties': {'@id': 'https://api.weather.gov/alerts/urn:oid:2.49.0.1.840.0.6d956cff9c1dfa46d7dd97d88afdebd1df13f0bf.001.1', '@type': 'wx:Alert', 'id': 'urn:oid:2.49.0.1.840.0.6d956cff9c1dfa46d7dd97d88afdebd1df13f0bf.001.1', 'areaDesc': 'Baraga; Marquette; Alger; Iron; Dickinson; Menominee; Delta', 'geocode': {'SAME': ['026013', '026103', '026003', '026071', '026043', '026109', '026041'], 'UGC': ['MIZ004', 'MIZ005', 'MIZ006', 'MIZ010', 'MIZ011', 'MIZ012', 'MIZ013']}, 'affectedZones': ['https://api.weather.gov/zones/forecast/MIZ004', 'https://api.weather.gov/zones/forecast/MIZ005', 'https://api.weather.gov/zones/forecast/MIZ006', 'https://api.weather.gov/zones/forecast/MIZ010', 'https://api.weather.gov/zones/forecast/MIZ011', 'https://api.weather.gov/zones/forecast/MIZ012', 'https://api.weather.gov/zones/forecast/MIZ013'], 'references': [{'@id': 'https://api.weather.gov/alerts/urn:oid:2.49.0.1.840.0.2c1eba8c5c472189100571050007501a3df7133a.001.1', 'identifier': 'urn:oid:2.49.0.1.840.0.2c1eba8c5c472189100571050007501a3df7133a.001.1', 'sender': 'w-nws.webmaster@noaa.gov', 'sent': '2024-12-26T15:02:00-05:00'}], 'sent': '2024-12-27T03:38:00-05:00', 'effective': '2024-12-27T03:38:00-05:00', 'onset': '2024-12-27T03:38:00-05:00', 'expires': '2024-12-27T13:00:00-05:00', 'ends': '2024-12-27T13:00:00-05:00', 'status': 'Actual', 'messageType': 'Update', 'category': 'Met', 'severity': 'Moderate', 'certainty': 'Likely', 'urgency': 'Expected', 'event': 'Dense Fog Advisory', 'sender': 'w-nws.webmaster@noaa.gov', 'senderName': 'NWS Marquette MI', 'headline': 'Dense Fog Advisory issued December 27 at 3:38AM EST until December 27 at 1:00PM EST by NWS Marquette MI', 'description' ...

# %%
# send raw json to bucket
import json
from google.cloud import storage

def upload_to_gcs(bucket_name, destination_blob_name, alert_data):
    # Initialize a storage client
    storage_client = storage.Client()

    # Get the bucket
    bucket = storage_client.bucket(bucket_name)

    # Create a blob object from the bucket
    blob = bucket.blob(destination_blob_name)

    # Convert the JSON data to a string
    alert_data_str = json.dumps(alert_data['features'])

    # Upload the JSON string to the blob
    blob.upload_from_string(alert_data_str)

    print(f"File uploaded to {destination_blob_name} in bucket {bucket_name}.")


bucket_name = "nws-alerts"
destination_blob_name = "daily-alerts-load.json"

upload_to_gcs(bucket_name, destination_blob_name, alert_data)
# Out:
# File uploaded to daily-alerts-load.json in bucket nws-alerts.

# %%
# Extract data from bucket and transform using pyspark
from pyspark.sql import SparkSession
# Step 1: Create a SparkSession
spark = SparkSession.builder.appName("JSONtoBigQuery").getOrCreate()
# Step 2: Read the JSON file
gcs_json_file_path = "gs://nws-alerts/daily-alerts-load.json"
json_file_path = "alert_data.json"
# Read JSON file into dataframe
df = spark.read.option("multiline", "true").json(json_file_path)
# df = spark.read.json(json_file_path)
# Step 2.1: Check the schema
df.printSchema()
# Out:
# root
#  |-- geometry: struct (nullable = true)
#  |    |-- coordinates: array (nullable = true)
#  |    |    |-- element: array (containsNull = true)
#  |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |-- element: double (containsNull = true)
#  |    |-- type: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- properties: struct (nullable = true)
#  |    |-- @id: string (nullable = true)
#  |    |-- @type: string (nullable = true)
#  |    |-- affectedZones: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- areaDesc: string (nullable = true)
#  |    |-- category: string (nullable = true)
#  |    |-- certainty: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- effective: string (nullable = true)
#  |    |-- ends: string (nullable = true)
#  |    |-- event: string (nullable = true)
#  |    |-- expires: string (nullable = true)
#  |    |-- geocode: struct (nullable = true)
#  |    |    |-- SAME: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- UGC: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |-- headline: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- instruction: string (nullable = true)
#  |    |-- messageType: string (nullable = true)
#  |    |-- onset: string (nullable = true)
#  |    |-- parameters: struct (nullable = true)
#  |    |    |-- AWIPSidentifier: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- BLOCKCHANNEL: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- EAS-ORG: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- NWSheadline: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- VTEC: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- WMOidentifier: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- eventEndingTime: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- eventMotionDescription: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- expiredReferences: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |-- references: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- @id: string (nullable = true)
#  |    |    |    |-- identifier: string (nullable = true)
#  |    |    |    |-- sender: string (nullable = true)
#  |    |    |    |-- sent: string (nullable = true)
#  |    |-- replacedAt: string (nullable = true)
#  |    |-- replacedBy: string (nullable = true)
#  |    |-- response: string (nullable = true)
#  |    |-- sender: string (nullable = true)
#  |    |-- senderName: string (nullable = true)
#  |    |-- sent: string (nullable = true)
#  |    |-- severity: string (nullable = true)
#  |    |-- status: string (nullable = true)
#  |    |-- urgency: string (nullable = true)
#  |-- type: string (nullable = true)

# %%
df.show(10)
# Out:
# +--------+--------------------+--------------------+-------+
# |geometry|                  id|          properties|   type|
# +--------+--------------------+--------------------+-------+
# |    NULL|https://api.weath...|{https://api.weat...|Feature|
# |    NULL|https://api.weath...|{https://api.weat...|Feature|
# |    NULL|https://api.weath...|{https://api.weat...|Feature|
# |    NULL|https://api.weath...|{https://api.weat...|Feature|
# |    NULL|https://api.weath...|{https://api.weat...|Feature|
# |    NULL|https://api.weath...|{https://api.weat...|Feature|
# |    NULL|https://api.weath...|{https://api.weat...|Feature|
# |    NULL|https://api.weath...|{https://api.weat...|Feature|
# |    NULL|https://api.weath...|{https://api.weat...|Feature|
# |    NULL|https://api.weath...|{https://api.weat...|Feature|
# +--------+--------------------+--------------------+-------+
# only showing top 10 rows

# %%
from pyspark.sql.functions import explode, col
# Clean df

df2 = df.select(col('properties.@id').alias('id'), 
                col('properties.@type').alias('type'), 
                col('properties.areaDesc'), 
                col('properties.geocode.SAME').alias('FIPS'),
                col('properties.affectedZones'),
                col('properties.references'),
                col('properties.sent'),
                col('properties.effective'),
                col('properties.onset'),
                col('properties.expires'),
                col('properties.ends'),
                col('properties.status'),
                col('properties.messageType'),
                col('properties.category'),
                col('properties.severity'),
                col('properties.certainty'),
                col('properties.urgency'),
                col('properties.event'),
                col('properties.senderName'),
                col('properties.headline'),
                col('properties.description'),
                col('properties.instruction'),
                col('properties.response'),
                col('properties.parameters')

)

df2.show(10)
# Out:
# +--------------------+--------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+-----------+--------+--------+---------+--------+--------------------+-------------------+--------------------+--------------------+--------------------+--------+--------------------+
# |                  id|    type|            areaDesc|                FIPS|       affectedZones|          references|                sent|           effective|               onset|             expires|                ends|status|messageType|category|severity|certainty| urgency|               event|         senderName|            headline|         description|         instruction|response|          parameters|
# +--------------------+--------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------+-----------+--------+--------+---------+--------+--------------------+-------------------+--------------------+--------------------+--------------------+--------+--------------------+
# |https://api.weath...|wx:Alert|Baraga; Marquette...|[026013, 026103, ...|[https://api.weat...|                  []|2024-12-27T06:49:...|2024-12-27T06:49:...|2024-12-27T06:49:...|2024-12-27T09:00:...|                NULL|Actual|      Alert|     Met|Moderate| Observed|Expected|Special Weather S...|   NWS Marquette MI|Special Weather S...|Although air temp...|                NULL| Execute|{[SPSMQT], [EAS, ...|
# |https://api.weath...|wx:Alert|Baraga; Marquette...|[026013, 026103, ...|[https://api.weat...|[{https://api.wea...|2024-12-27T03:38:...|2024-12-27T03:38:...|2024-12-27T03:38:...|2024-12-27T13:00:...|2024-12-27T13:00:...|Actual|     Update|     Met|Moderate|   Likely|Expected|  Dense Fog Advisory|   NWS Marquette MI|Dense Fog Advisor...|* WHAT...Visibili...|If driving, slow ...| Execute|{[NPWMQT], [EAS, ...|
# |https://api.weath...|wx:Alert|Baraga; Marquette...|[026013, 026103, ...|[https://api.weat...